# %%
print("hello world")
# Out:
# hello world

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Bar Graph

# %%
bar_labels = ['A','B','C','D']
bar_heights = [3,7,4,2]

plt.bar(bar_labels, bar_heights)
plt.show()

# %% [markdown]
# # Scatter Graph

# %%
x = [1,2,3,4,5,6]
y = [5,9,8,7,2,0]

plt.scatter(x,y)
plt.show()
